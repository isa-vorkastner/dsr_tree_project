# %%
# !pip install geemap retry rasterio

import ee
import geemap
import multiprocessing
import requests
import shutil
from retry import retry
from google.colab import drive
import pandas as pd
# !pip install geopandas
import geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git clone https://github.com/WinnieCP/dsr_tree_project.git
# Out:
# Cloning into 'dsr_tree_project'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 107 (delta 50), reused 80 (delta 30), pack-reused 0
# Receiving objects: 100% (107/107), 66.69 KiB | 1.08 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
from dsr_tree_project.create_data.utils import download_image_tiles_from_ee

drive.mount('/gdrive')
# Trigger the authentication flow.
ee.Authenticate()
ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')
# Out:
# Mounted at /gdrive
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ecesU6VbpKpNbGywoXcaj52S02_ED_f9INx_TIpbbvg&tc=ViByYFEfy8zvxU5Cy-aE8CY89uJ1pE7UgPsw4vL4Blk&cc=Yr-WmhrhnahClvMjdLlxMc2thTGKz87wm-KVCSZVOYI
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AVHEtk6PDd6ZLoQBoocBRBSwjbNI8NsEiqjJ0MTverrR4VGQYlN1gQBrqAE
#
# Successfully saved authorization token.

# %% [markdown]
# ### MODIFIED VERSION FOR PULLING IMAGES FOR THE SPECIFIC MODEL

# %%
# Download images for training set
center_pt = [13.319675, 52.496394] # Wilmersdorf Training
#center_pt = [13.42378, 52.535262] # Validation
#center_pt = [13.453000, 52.502697] # Test - east of share now
#center_pt = [13.462500, 52.508800] # Ostkreuz
#center_pt = [13.334511, 52.501573] # DSR
channels = ['R', 'G', 'B']# ['N', 'R', 'G']#
tiles, params = download_image_tiles_from_ee(center = center_pt,
                                 rows=16,
                                 cols=10,
                                 img_dim=[1024, 640],
                                 rel_overlap=0,
                                 scale=1,
                                 out_dir = '/gdrive/MyDrive/Berliner_Baeume/training_dataset/Wilmersdorf_1024x640/RGB', #'',#
                                 channels = channels,
                                 processes = 25,
                                 format = 'GEO_TIFF',
                                 preview_only = False,
                                 min_num_trees = None,
                                 path_to_tree_data = '/gdrive/MyDrive/Berliner_Baeume/Baumkataster_-_Berlin.csv',
                                 min_kronedurch = None,
                                 only_tiles_with_medium_amount_of_labels = False
                                 )

# %%
# Download images for validation set
center_pt = [13.42378, 52.535262]
channels = ['R', 'G', 'B']#['N', 'R', 'G']#
tiles, params = download_image_tiles_from_ee(center = center_pt, 
                                 rows=6, 
                                 cols=4, 
                                 img_dim=[1024, 640], 
                                 rel_overlap=0,
                                 scale=1,
                                 out_dir ='/gdrive/MyDrive/Berliner_Baeume/validation_dataset/validation_1024x640/RGB',
                                 channels = channels,
                                 processes = 25,
                                 format = 'GEO_TIFF',
                                 preview_only = False,
                                 min_num_trees = None, 
                                 path_to_tree_data = '/gdrive/MyDrive/Berliner_Baeume/Baumkataster_-_Berlin.csv',
                                 min_kronedurch = None,
                                 only_tiles_with_medium_amount_of_labels = False
                                 )
